# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pymongo

# %%
url='https://en.wikipedia.org/wiki/Kanye_West_albums_discography'
raw_data=requests.get(url).text

# %%
soup=BeautifulSoup(raw_data,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Kanye West albums discography - Wikipedia
#   </title>
#   <script>
# ...

# %%
studio_table=soup.find('table',{'class':'wikitable plainrowheaders'})
print(studio_table.text)
# Out:
# List of studio albums, with selected chart positions, sales figures and certifications
#
#
# Title
#
# Details
#
# Peak chart positions
#
# Sales
#
# Certifications
#
#
# US[4]
#
# USR&B[11]
#
# USRap[12]
#
# AUS[13]
#
# CAN[14]
#
# GER[15]
#
# IRL[16]
#
# NZ[17]
#
# SWI[18]
#
# UK[9]
#
#
# The College Dropout
#
#
# Released: February 10, 2004[19]
# Label: Roc-A-Fella, Def Jam
# Formats: CD, LP, digital download
#
# 2
# 1
# 5
# —
# —
# 77
# 13
# —
# 96
# 12
#
#
# US: 3,358,000[20]
#
#
# RIAA: 3× Platinum[2]
# BPI: 2× Platinum[21]
# MC: Platinum[22]
# RMNZ: Gold[23]
#
#
# Late Registration
#
#
# Released: August 30, 2005[24]
# Label: Roc-A-Fella, Def Jam
# Formats: CD, LP, digital download
#
# 1
# 1
# 1
# 14
# 1
# 14
# 2
# 11
# 9
# 2
#
#
# US: 3,100,000[7]
#
#
# RIAA: 3× Platinum[2]
# ARIA: Platinum[25]
# BPI: 2× Platinum[21]
# IRMA: 2× Platinum[26]
# MC: 2× Platinum[22]
# RMNZ: Platinum[27]
#
#
# Graduation
#
#
# Released: September 11, 2007[28]
# Label: Roc-A-Fella, Def Jam
# ...

# %%
#album_name=[]
#for record in studio_table.findAll('th',scope='row'):
 #   album_name.append(record.text)
    
#album_name=[a.strip() for a in album_name]
#album_name

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-5fb924ae39ac> in <module>
# ----> 1 pd.DataFrame(studio_table.text)
#
# ~/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466                                    dtype=values.dtype, copy=False)
#     467             else:
# --> 468                 raise ValueError('DataFrame constructor not properly called!')
#     469
#     470         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!
